# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliethLopez/dlaicoursePractica/blob/master/10.Sarcasm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Usamos los datos Sarcasm
# En este cuaderno veremos los gráficos con varios valores de embedding_dim y vocab_size.

# %%
# Run this to ensure TensorFlow 2.x is used
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

# %%
import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 5000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"
training_size = 20000

# %%
# !wget --no-check-certificate \
    https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json \
    -O /tmp/sarcasm.json
# Out:
# --2020-07-18 23:50:12--  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/sarcasm.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.119.128, 108.177.126.128, 108.177.127.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.119.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5643545 (5.4M) [application/json]
# Saving to: ‘/tmp/sarcasm.json’
#
# /tmp/sarcasm.json   100%[===================>]   5.38M  --.-KB/s    in 0.05s
#
# 2020-07-18 23:50:12 (108 MB/s) - ‘/tmp/sarcasm.json’ saved [5643545/5643545]

# %%
with open("/tmp/sarcasm.json", 'r') as f:
    datastore = json.load(f)

sentences = []
labels = []

for item in datastore:
    sentences.append(item['headline'])
    labels.append(item['is_sarcastic'])

# %%
training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
# Need this block to get it to work with TensorFlow 2.x
import numpy as np
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 100, 16)           80000
# _________________________________________________________________
# global_average_pooling1d_7 ( (None, 16)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 24)                408
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 25
# =================================================================
# Total params: 80,433
# Trainable params: 80,433
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 30
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/30
# 625/625 - 2s - loss: 0.6610 - accuracy: 0.5923 - val_loss: 0.5723 - val_accuracy: 0.7615
# Epoch 2/30
# 625/625 - 2s - loss: 0.4385 - accuracy: 0.8235 - val_loss: 0.3919 - val_accuracy: 0.8360
# Epoch 3/30
# 625/625 - 2s - loss: 0.3307 - accuracy: 0.8643 - val_loss: 0.3623 - val_accuracy: 0.8490
# Epoch 4/30
# 625/625 - 2s - loss: 0.2893 - accuracy: 0.8811 - val_loss: 0.3541 - val_accuracy: 0.8502
# Epoch 5/30
# 625/625 - 2s - loss: 0.2618 - accuracy: 0.8936 - val_loss: 0.3564 - val_accuracy: 0.8483
# Epoch 6/30
# 625/625 - 2s - loss: 0.2435 - accuracy: 0.9013 - val_loss: 0.3824 - val_accuracy: 0.8380
# Epoch 7/30
# 625/625 - 2s - loss: 0.2294 - accuracy: 0.9063 - val_loss: 0.3808 - val_accuracy: 0.8438
# Epoch 8/30
# 625/625 - 2s - loss: 0.2167 - accuracy: 0.9129 - val_loss: 0.3784 - val_accuracy: 0.8439
# Epoch 9/30
# 625/625 - 2s - loss: 0.2066 - accuracy: 0.9168 - val_loss: 0.3913 - val_accuracy: 0.8427
# Epoch 10/30
# 625/625 - 2s - loss: 0.1992 - accuracy: 0.9190 - val_loss: 0.4127 - val_accuracy: 0.8374
# Epoch 11/30
# 625/625 - 2s - loss: 0.1914 - accuracy: 0.9234 - val_loss: 0.4306 - val_accuracy: 0.8340
# Epoch 12/30
# 625/625 - 2s - loss: 0.1860 - accuracy: 0.9269 - val_loss: 0.4289 - val_accuracy: 0.8386
# Epoch 13/30
# 625/625 - 2s - loss: 0.1793 - accuracy: 0.9288 - val_loss: 0.4511 - val_accuracy: 0.8340
# Epoch 14/30
# 625/625 - 2s - loss: 0.1759 - accuracy: 0.9302 - val_loss: 0.4592 - val_accuracy: 0.8341
# Epoch 15/30
# 625/625 - 2s - loss: 0.1714 - accuracy: 0.9336 - val_loss: 0.4798 - val_accuracy: 0.8305
# Epoch 16/30
# 625/625 - 2s - loss: 0.1678 - accuracy: 0.9352 - val_loss: 0.4916 - val_accuracy: 0.8307
# Epoch 17/30
# 625/625 - 2s - loss: 0.1660 - accuracy: 0.9350 - val_loss: 0.5047 - val_accuracy: 0.8281
# Epoch 18/30
# 625/625 - 2s - loss: 0.1615 - accuracy: 0.9377 - val_loss: 0.5382 - val_accuracy: 0.8162
# Epoch 19/30
# 625/625 - 2s - loss: 0.1575 - accuracy: 0.9406 - val_loss: 0.5322 - val_accuracy: 0.8258
# Epoch 20/30
# 625/625 - 2s - loss: 0.1584 - accuracy: 0.9388 - val_loss: 0.5696 - val_accuracy: 0.8207
# Epoch 21/30
# 625/625 - 2s - loss: 0.1523 - accuracy: 0.9423 - val_loss: 0.5578 - val_accuracy: 0.8237
# Epoch 22/30
# 625/625 - 2s - loss: 0.1504 - accuracy: 0.9430 - val_loss: 0.5680 - val_accuracy: 0.8249
# Epoch 23/30
# 625/625 - 2s - loss: 0.1493 - accuracy: 0.9439 - val_loss: 0.5935 - val_accuracy: 0.8249
# Epoch 24/30
# 625/625 - 2s - loss: 0.1477 - accuracy: 0.9431 - val_loss: 0.5973 - val_accuracy: 0.8252
# Epoch 25/30
# 625/625 - 2s - loss: 0.1455 - accuracy: 0.9454 - val_loss: 0.6123 - val_accuracy: 0.8255
# Epoch 26/30
# 625/625 - 2s - loss: 0.1430 - accuracy: 0.9463 - val_loss: 0.6177 - val_accuracy: 0.8229
# Epoch 27/30
# 625/625 - 2s - loss: 0.1425 - accuracy: 0.9471 - val_loss: 0.6296 - val_accuracy: 0.8190
# Epoch 28/30
# 625/625 - 2s - loss: 0.1416 - accuracy: 0.9466 - val_loss: 0.6392 - val_accuracy: 0.8182
# Epoch 29/30
# 625/625 - 2s - loss: 0.1387 - accuracy: 0.9477 - val_loss: 0.6693 - val_accuracy: 0.8192
# Epoch 30/30
# 625/625 - 2s - loss: 0.1390 - accuracy: 0.9482 - val_loss: 0.6651 - val_accuracy: 0.8195

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

vocab_size = 10000
embedding_dim = 16
max_length = 100

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

vocab_size = 1000
embedding_dim = 16
max_length = 100

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

vocab_size = 1000
embedding_dim = 32
max_length = 100

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

vocab_size = 500
embedding_dim = 16
max_length = 100

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

vocab_size = 5000
embedding_dim = 64
max_length = 100

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

vocab_size = 5000
embedding_dim = 32
max_length = 100

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

vocab_size = 5000
embedding_dim = 16
max_length = 100

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_sentence(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_sentence(training_padded[0]))
print(training_sentences[2])
print(labels[2])
# Out:
# former <OOV> store clerk sues over secret 'black <OOV> for minority shoppers ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?
# mom starting to fear son's web series closest thing she will have to grandchild
# 1

# %%
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) # shape: (vocab_size, embedding_dim)
# Out:
# (10000, 16)

# %%
import io

out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, vocab_size):
  word = reverse_word_index[word_num]
  embeddings = weights[word_num]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# %%
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')

# %%
sentence = ["granny starting to fear spiders in the garden might be real", "game of thrones season finale showing this sunday night"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
